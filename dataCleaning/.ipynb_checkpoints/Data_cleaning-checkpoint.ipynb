# %%
import pandas as pd

# %%
df = pd.read_csv("./data.txt")
df = df.rename(columns=lambda x: x.strip())
df = df.drop(['C/A','UNIT','SCP','DIVISION','DESC'],axis = 1)
df['LINENAME'] = df['LINENAME'].str.split("")

# %%
df["TIME"] = df["TIME"].str.split(':').str[0].astype(int)

# %%
df["TIME"] = (df["TIME"]/4).astype(int)

# %%
df = df.LINENAME.apply(pd.Series) \
    .merge(df, right_index = True, left_index = True) \
    .drop(["LINENAME"], axis = 1) \
    .melt(id_vars = ['STATION', 'DATE','TIME','ENTRIES','EXITS'], value_name = "LINENAME") \
    .drop("variable", axis = 1) \
    .dropna()

# %%
def process_line(df):
    return df.groupby(['STATION','DATE','TIME'], as_index=False).agg({"ENTRIES": "sum","EXITS": "sum"})

# %%
df = df[df.LINENAME != '']
lines = df.LINENAME.unique()[1:]

# %%
df_dict = {}
for line in lines:
    df_dict[line] = process_line(df[df.LINENAME == line])
    df_dict[line] = df_dict[line].sort_values(by=['DATE','TIME'])
    #df_dict[line].to_csv(line+"line.csv")

# %%
for key in df_dict.keys():
    stations = df_dict[key].STATION.unique()
    df_dict[key].ENTRIES = abs(df_dict[key].ENTRIES - df_dict[key].shift(len(stations)).ENTRIES)
    df_dict[key].EXITS = abs(df_dict[key].EXITS - df_dict[key].shift(len(stations)).EXITS)
    df_dict[key].dropna()
    
    df_dict[key] = df_dict[key].fillna(0.0)
    df_dict[key].to_csv(key+"line.csv",index=True,sep=',')

# %%
# Out:
#               STATION        DATE  TIME       ENTRIES         EXITS
# 0      14 ST-UNION SQ  04/13/2019     0  0.000000e+00  0.000000e+00
# 42              23 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 84              25 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 126             28 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 168   34 ST-HERALD SQ  04/13/2019     0  0.000000e+00  0.000000e+00
# 210             36 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 252         4 AV-9 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 294   42 ST-PORT AUTH  04/13/2019     0  0.000000e+00  0.000000e+00
# 336             45 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 378             46 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 420             49 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 462          4AV-9 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 504        5 AV/59 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 546             53 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 588        57 ST-7 AV  04/13/2019     0  0.000000e+00  0.000000e+00
# 630             59 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 672   63 DR-REGO PARK  04/13/2019     0  0.000000e+00  0.000000e+00
# 714             65 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 756             67 AV  04/13/2019     0  0.000000e+00  0.000000e+00
# 798    74 ST-BROADWAY  04/13/2019     0  0.000000e+00  0.000000e+00
# 840             77 ST  04/13/2019     0  0.000000e+00  0.000000e+00
# 882          8 ST-NYU  04/13/2019     0  0.000000e+00  0.000000e+00
