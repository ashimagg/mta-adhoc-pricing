# %%
import pandas as pd

# %%
df = pd.read_csv("./data.txt")
df = df.rename(columns=lambda x: x.strip())
df = df.drop(['C/A','UNIT','SCP','DIVISION','DESC'],axis = 1)
df['LINENAME'] = df['LINENAME'].str.split("")

# %%
df = df.LINENAME.apply(pd.Series) \
    .merge(df, right_index = True, left_index = True) \
    .drop(["LINENAME"], axis = 1) \
    .melt(id_vars = ['STATION', 'DATE','TIME','ENTRIES','EXITS'], value_name = "LINENAME") \
    .drop("variable", axis = 1) \
    .dropna()

# %%
def process_line(df):
    return df.groupby(['STATION','DATE','TIME'], as_index=False).agg({"ENTRIES": "sum","EXITS": "sum"})

# %%
df = df[df.LINENAME != '']
lines = df.LINENAME.unique()[1:]

# %%
df_dict = {}
for line in lines:
    df_dict[line] = process_line(df[df.LINENAME == line])
    df_dict[line] = df_dict[line].sort_values(by=['DATE','TIME'])
    df_dict[line].to_csv(line+"line.csv")

# %%
df_dict.keys()
# Out:
# dict_keys(['A', 'B', 'L', 'J', 'R', 'F', 'S', 'Q', 'D', 'E', 'M', 'C', '2', 'G', '1', '4', '6', '3', '7', '5', 'Z', 'W'])

# %%
# Out:
#               STATION        DATE      TIME     ENTRIES       EXITS
# 0              104 ST  04/13/2019  00:00:00  1690711844   989486675
# 84             125 ST  04/13/2019  00:00:00   506894382   421257880
# 169            145 ST  04/13/2019  00:00:00   113373327   115361301
# 187            168 ST  04/13/2019  00:00:00    86612253    52019003
# 230            175 ST  04/13/2019  00:00:00   378255415   306922715
# 314            190 ST  04/13/2019  00:00:00  1453739229  1847474244
# 356    34 ST-PENN STA  04/13/2019  00:00:00  1666859967  1578149339
# 441   42 ST-PORT AUTH  04/13/2019  00:00:00  7250232418  6083034059
# 525    59 ST COLUMBUS  04/13/2019  00:00:00  3421271715  2996513172
# 736   AQUEDUCT RACETR  04/13/2019  00:00:00    54547489    17274355
# 820       BEACH 25 ST  04/13/2019  00:00:00   646787446   969615440
# 862       BEACH 36 ST  04/13/2019  00:00:00     4904885     4915467
# 904       BEACH 44 ST  04/13/2019  00:00:00     2358284     2086089
# 946       BEACH 60 ST  04/13/2019  00:00:00   128544750    11534152
# 988       BEACH 67 ST  04/13/2019  00:00:00    11870455    11280887
# 1156     BROADWAY JCT  04/13/2019  00:00:00    62012024    58262032
# 1198         CANAL ST  04/13/2019  00:00:00   961816284   603604467
# 1241      CHAMBERS ST  04/13/2019  00:00:00  1942788050   833321422
# 1325        EUCLID AV  04/13/2019  00:00:00    26302773    12058740
# 1367     FAR ROCKAWAY  04/13/2019  00:00:00   844059150   172353993
# 1539         GRANT AV  04/13/2019  00:00:00  1229650800  1778164157
# 1581          HIGH ST  04/13/2019  00:00:00  2751210359  3700065696
